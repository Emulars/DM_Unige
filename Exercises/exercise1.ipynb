# %%
import networkx as nx
import matplotlib.pyplot as plt

# Specify seed for reproducibility
seed = 668273

# Each list entry corresponds to the degree of a node.
z = [5, 3, 3, 3, 3, 2, 2, 2, 1, 1, 1 ]

# Check if the degree sequence is valid
print("Is the given degree sequence valid:" + nx.is_graphical(z).__str__())
# Create a graph from the degree sequence
G = nx.configuration_model(z, seed=seed)

# Compute and print its basic properties
print("Number of nodes: ", G.number_of_nodes())
print("Number of edges: ", G.number_of_edges())
print("Diameter: ", nx.diameter(G))
print("Adjacency list: ")

# Print and save on file the adjacency list
with open("exercise1_graph.adjlist", "w") as f:
    for line in nx.generate_adjlist(G):
        print(line)
        f.write(line + "\n")
# Out:
# Is the given degree sequence valid:True
# Number of nodes:  11
# Number of edges:  13
# Diameter:  7
# Adjacency list:
# 0 1 7 2 0
# 1 9 3
# 2 6 4
# 3 10 7
# 4 5 6
# 5 8
# 6
# 7
# 8
# 9
# 10

# %%
# Draw the graph
nx.draw(G, with_labels=True)
plt.show()

# %%
# Plot the degree distribution
degrees = [G.degree(n) for n in G.nodes()]
plt.hist(degrees, bins=range(1, max(degrees) + 2), align='left', rwidth=0.8)
plt.title("Degree Distribution")
plt.xlabel("Degree")
plt.ylabel("Frequency")
plt.show()
